# %%
# %pip install --upgrade pip

# %%
# pip install --force-reinstall git+https://github.com/khanh-at-gex/gex-msgraph.git

# %%
# %pip install python-calamine

# %%
# Import necessary libraries
from dotenv import load_dotenv

load_dotenv()
from gex_msgraph import GraphClient, FileItem

# %%
ROOT_DIR = r"2026\Project Phoenix\04. Working files"

# %%
client = GraphClient("das_u1")
# await client.__aenter__()

# items = await client.list_files(ROOT_DIR)
# print(f"Connected. Found {len(items)} items at the drive root.")

# %%
import pandas as pd

# 1. All folders (relative to ROOT_DIR)
items = await client.list_files(ROOT_DIR)
df_folders = pd.DataFrame(items)[["name", "path"]].rename(
    columns={"name": "folder_name", "path": "folder_path"}
)
# df_folders

# 2. All .xlsx files (relative to ROOT_DIR)
xlsx_files = await client.walk(ROOT_DIR, pattern="*.xls*")
df_xlsx = pd.DataFrame(xlsx_files)[["name", "path", "modified"]].rename(
    columns={"name": "file_name", "path": "file_path", "modified": "file_modified"}
)
df_xlsx["folder_path"] = (
    df_xlsx["file_path"].str.rsplit("/", n=1).str[0].str.removeprefix(ROOT_DIR + "/")
)

# df_list_files = df_folders.merge(df_xlsx, on="folder_path", how="left")


df_list_files = df_folders.merge(df_xlsx, on="folder_path", how="left")
display(df_list_files[~df_list_files["folder_name"].str.startswith("00")])
# Out:
#         folder_name                                             folder_path  \
# 2         01. GELEX        2026/Project Phoenix/04. Working files/01. GELEX
# 3           02. GEE          2026/Project Phoenix/04. Working files/02. GEE
# 4        03. CADIVI       2026/Project Phoenix/04. Working files/03. CADIVI
# 5           05. THI          2026/Project Phoenix/04. Working files/05. THI
# 6           06. MEE          2026/Project Phoenix/04. Working files/06. MEE
# 7           07. HEM          2026/Project Phoenix/04. Working files/07. HEM
# 8          08. EMIC         2026/Project Phoenix/04. Working files/08. EMIC
# 9           09. CFT          2026/Project Phoenix/04. Working files/09. CFT
# 10     10. Phatdien     2026/Project Phoenix/04. Working files/10. Phatdien
# 11         11. GETC         2026/Project Phoenix/04. Working files/11. GETC
# 12         11. GETC         2026/Project Phoenix/04. Working files/11. GETC
# 13    12. GELEXTECH    2026/Project Phoenix/04. Working files/12. GELEXTECH
# 14  13. GELEXINVEST  2026/Project Phoenix/04. Working files/13. GELEXINVEST
# 15          14. GEL          2026/Project Phoenix/04. Working files/14. GEL
# 16          15. VGC          2026/Project Phoenix/04. Working files/15. VGC
# 17    16. Viwasupco    2026/Project Phoenix/04. Working files/16. Viwasupco
# 18          17. PXL          2026/Project Phoenix/04. Working files/17. PXL
# 19          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 20          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 21          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 22      19. TITANHP      2026/Project Phoenix/04. Working files/19. TITANHP
# 23       20. WADACO       2026/Project Phoenix/04. Working files/20. WADACO
# 24    21. TitanCorp    2026/Project Phoenix/04. Working files/21. TitanCorp
# 25         22. BSG1         2026/Project Phoenix/04. Working files/22. BSG1
# 26         22. BSG1         2026/Project Phoenix/04. Working files/22. BSG1
#  '2026/Project Phoenix/04. Working files/23. BSG2/[BSG2]_CFForecast_2026_2030_1 - BT2.xlsm',
#  '2026/Project Phoenix/04. Working files/23. BSG2/[DA06]_CFForecast_2026_2030_1 - DA06.xlsm',
#  '2026/Project Phoenix/04. Working files/23. BSG2/[DA07]_CFForecast_2026_2030_1 - DA07.xlsm',
#  '2026/Project Phoenix/04. Working files/23. BSG2/[DA08]_CFForecast_2026_2030_1 - DA08.xlsm',
#  '2026/Project Phoenix/04. Working files/23. BSG2/[DA09]_CFForecast_2026_2030_1 - DA09.xlsm',
#  '2026/Project Phoenix/04. Working files/23. BSG2/[DA11]_CFForecast_2026_2030_1 - DA11.xlsm',
#  '2026/Project Phoenix/04. Working files/24. TTP/[DA05]_CFForecast_2026_2030.xlsm',
#  '2026/Project Phoenix/04. Working files/24. TTP/[DA10]_CFForecast_2026_2030.xlsm',
#  '2026/Project Phoenix/04. Working files/24. TTP/[DA12]_CFForecast_2026_2030.xlsm',
#  '2026/Project Phoenix/04. Working files/24. TTP/[TTP]_CFForecast_2026_2030.xlsm',
#  '2026/Project Phoenix/04. Working files/25. EIB/EIB_CFForecast_2026_2030.xlsm']

# %%
df_report, df_report_status = await client.read_excel_many(
    list_path_excel,
    sheet="Report",
    on_error="skip",
    on_missing_sheet="skip",
    skiprows=1,
    return_status=True,
    usecols="A:M",
)
# display(df_report.head())
# display(df_report_status)

print(df_report.columns)
# Out:
# Index(['Code', 'Phân cấp đơn vị', 'Mã đơn vị', 'Tên đơn vị', 'Khoản mục',
#        'Chỉ tiêu', 'Năm', 'Quý', 'Số tiền tổng',
#        'Nguồn thông tin\n(Các ghi chú khác về dữ liệu, nguồn thông tin,...nếu cần để sau có thể follow up',
#        'Phân loại ổn định và không ổn định',
#        'Phân loại Bên trong và bên ngoài', 'Đối tượng giao dịch kinh tế',
#        '_source'],
#       dtype='str')

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\khanh.nguyen-quoc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'ma_don_vi'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df_report[df_report['ma_don_vi']=='THI']
#
# File c:\Users\khanh.nguyen-quoc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File c:\Users\khanh.nguyen-quoc\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'ma_don_vi'

# %%
column_mapping = {
    "Code": "code",
    "Phân cấp đơn vị": "phan_cap_don_vi",
    "Mã đơn vị": "ma_don_vi",
    "Tên đơn vị": "ten_don_vi",
    "Khoản mục": "khoan_muc",
    "Chỉ tiêu": "chi_tieu",
    "Năm": "nam",
    "Quý": "quy",
    "Số tiền tổng": "so_tien_tong",
    "Nguồn thông tin\n(Các ghi chú khác về dữ liệu, nguồn thông tin,...nếu cần để sau có thể follow up": "nguon_thong_tin",
    "Phân loại ổn định và không ổn định": "phan_loai_on_dinh_khong_on_dinh",
    "Phân loại Bên trong và bên ngoài": "phan_loai_ben_trong_ben_ngoai",
    "Đối tượng giao dịch kinh tế": "doi_tuong_giao_dich_kinh_te",
    "_source": "source",
}
df_report = df_report.rename(columns=column_mapping)
df_report = df_report[list(column_mapping.values())]
# display(df_report.head())

# %%
df_report[df_report['ma_don_vi']=='THI']
# Out:
#           code phan_cap_don_vi ma_don_vi                     ten_don_vi  \
# 0     CF01.S.E         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 1     CF01.U.E         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 2     CF02.U.E         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 3     CF03.S.E         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 4     CF04.U.E         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# ...        ...             ...       ...                            ...
# 2278         0         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 2279         0         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 2280         0         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 2281         0         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
# 2282         0         3. CTTV       THI  Công ty Cổ phần Thiết bị điện
#
#      khoan_muc  \
# 0          CFO
# 1          CFO
# 2          CFO
# 3          CFO
# 4          CFO
# ...        ...
# 2278       NaN
# 2279       NaN
# 2280       NaN
# 2281       NaN
# 2282       NaN
#
#                                                                            chi_tieu  \
# 0                                                           1. Lợi nhuận trước thuế
# 1                                                           1. Lợi nhuận trước thuế
# 2                                                          - Khấu hao TSCĐ và BĐSĐT
# 3                                                              - Các khoản dự phòng
# 4     - Lãi/lỗ chênh lệch tỷ giá hối đoái (đánh giá lại khoản mục tiền tệ ngoại tệ)
# ...                                                                             ...
# 2278                                                                            NaN
# 2279                                                                            NaN
# 2280                                                                            NaN
# 2281                                                                            NaN
# 2282                                                                            NaN
#
#          nam  quy  so_tien_tong  nguon_thong_tin  \
# 0     2026.0   Q1  39362.335241              NaN
# 1     2026.0   Q1   9145.701354              NaN
# 2     2026.0   Q1  10520.084556              NaN
# 3     2026.0   Q1         -5839              NaN
# 4     2026.0   Q1          1186              NaN
# ...      ...  ...           ...              ...
# 2278     NaN  NaN           0.0              NaN
# 2279     NaN  NaN           0.0              NaN
# 2280     NaN  NaN           0.0              NaN
# 2281     NaN  NaN           0.0              NaN
# 2282     NaN  NaN           0.0              NaN
#
#      phan_loai_on_dinh_khong_on_dinh phan_loai_ben_trong_ben_ngoai  \
# 0                            Ổn định                     Bên ngoài
# 1                      Không ổn định                     Bên ngoài
# 2                      Không ổn định                     Bên ngoài
# 3                            Ổn định                     Bên ngoài
# 4                      Không ổn định                     Bên ngoài
# ...                              ...                           ...
# 2278                             NaN                           NaN
# 2279                             NaN                           NaN
# 2280                             NaN                           NaN
# 2281                             NaN                           NaN
# 2282                             NaN                           NaN
#
#      doi_tuong_giao_dich_kinh_te  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 2278                         NaN
# 2279                         NaN
# 2280                         NaN
# 2281                         NaN
# 2282                         NaN
#
#                                                                                       source
# 0     2026/Project Phoenix/04. Working files/00. Template/template_CFForecast_2026_2030.xlsm
# 1     2026/Project Phoenix/04. Working files/00. Template/template_CFForecast_2026_2030.xlsm
# 2     2026/Project Phoenix/04. Working files/00. Template/template_CFForecast_2026_2030.xlsm
# 3     2026/Project Phoenix/04. Working files/00. Template/template_CFForecast_2026_2030.xlsm
# 4     2026/Project Phoenix/04. Working files/00. Template/template_CFForecast_2026_2030.xlsm
# ...                                                                                      ...
# 2278             2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
# 2279             2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
# 2280             2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
# 2281             2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
# 2282             2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
#
# [691 rows x 14 columns]

# %%
df_report.columns
# Out:
# Index(['code', 'phan_cap_don_vi', 'ma_don_vi', 'ten_don_vi', 'khoan_muc',
#        'chi_tieu', 'nam', 'quy', 'so_tien_tong', 'nguon_thong_tin',
#        'phan_loai_on_dinh_khong_on_dinh', 'phan_loai_ben_trong_ben_ngoai',
#        'doi_tuong_giao_dich_kinh_te', 'source'],
#       dtype='str')

# %%
df_key_drivers, df_key_drivers_status = await client.read_excel_many(
    list_path_excel,
    sheet="Key drivers",
    on_error="skip",
    on_missing_sheet="skip",
    skiprows=1,
    return_status=True,
    usecols="A:J",
)
df_key_drivers.columns
# display(df_key_drivers)
# display(df_key_drivers_status)
# Out:
# Index(['Group', 'Code', 'Phân cấp đơn vị', 'Mã đơn vị', 'Tên đơn vị',
#        'Chỉ tiêu', 'Cấu phần value chain', 'Key drivers',
#        'Phân loại Ổn định & Không ổn định',
#        'Rationale ổn định or không ổn định', '_source',
#        'Phân loại ổn định và không ổn định',
#        'Phân loại Bên trong và bên ngoài'],
#       dtype='str')

# %%
# Merge the two near-duplicate columns before renaming
df_key_drivers["Phân loại Ổn định & Không ổn định"] = (
    df_key_drivers["Phân loại Ổn định & Không ổn định"]
    .combine_first(df_key_drivers["Phân loại ổn định và không ổn định"])
)
df_key_drivers = df_key_drivers.drop(columns=["Phân loại ổn định và không ổn định"])

column_mapping = {
    "Group": "group",
    "Code": "code",
    "Phân cấp đơn vị": "phan_cap_don_vi",
    "Mã đơn vị": "ma_don_vi",
    "Tên đơn vị": "ten_don_vi",
    "Chỉ tiêu": "chi_tieu",
    "Cấu phần value chain": "cau_phan_value_chain",
    "Key drivers": "key_drivers",
    "Phân loại Ổn định & Không ổn định": "phan_loai_on_dinh_khong_on_dinh",
    "Rationale ổn định or không ổn định": "rationale_on_dinh_khong_on_dinh",
    "Phân loại Bên trong và bên ngoài": "phan_loai_ben_trong_ben_ngoai",
    "_source": "source",
}
df_key_drivers = df_key_drivers.rename(columns=column_mapping)
df_key_drivers = df_key_drivers[list(column_mapping.values())]
# display(df_key_drivers.head())

# %%
df_key_drivers.columns
# Out:
# Index(['group', 'code', 'phan_cap_don_vi', 'ma_don_vi', 'ten_don_vi',
#        'chi_tieu', 'cau_phan_value_chain', 'key_drivers',
#        'phan_loai_on_dinh_khong_on_dinh', 'rationale_on_dinh_khong_on_dinh',
#        'phan_loai_ben_trong_ben_ngoai', 'source'],
#       dtype='str')

# %%
df_ratio_commit, df_ratio_commit_status = await client.read_excel_many(
    list_path_excel,
    sheet="Ratio_commit",
    on_error="skip",
    on_missing_sheet="skip",
    skiprows=1,
    return_status=True,
    usecols="A:J",
)
# display(df_ratio_commit.head())
# display(df_ratio_commit_status)
df_ratio_commit.columns
# Out:
# Index(['Phân cấp đơn vị', 'Mã đơn vị', 'Tên đơn vị', 'Chỉ tiêu cam kết',
#        'Công thức', 'Giá trị cam kết', 'Năm', 'Quý', 'Giá trị thực hiện',
#        'Status (ok/ break)', '_source', 'Nguồn số liệu', 'Định kỳ'],
#       dtype='str')

# %%
column_mapping = {
    "Phân cấp đơn vị": "phan_cap_don_vi",
    "Mã đơn vị": "ma_don_vi",
    "Tên đơn vị": "ten_don_vi",
    "Chỉ tiêu cam kết": "chi_tieu_cam_ket",
    "Công thức": "cong_thuc",
    "Giá trị cam kết": "gia_tri_cam_ket",
    "Năm": "nam",
    "Quý": "quy",
    "Giá trị thực hiện": "gia_tri_thuc_hien",
    "Status (ok/ break)": "status",
    "_source": "source",
    "Nguồn số liệu": "nguon_so_lieu",
    "Định kỳ": "dinh_ky",
}
df_ratio_commit = df_ratio_commit.rename(columns=column_mapping)
df_ratio_commit = df_ratio_commit[list(column_mapping.values())]
# display(df_ratio_commit.head())
df_ratio_commit.columns
# Out:
# Index(['phan_cap_don_vi', 'ma_don_vi', 'ten_don_vi', 'chi_tieu_cam_ket',
#        'cong_thuc', 'gia_tri_cam_ket', 'nam', 'quy', 'gia_tri_thuc_hien',
#        'status', 'source', 'nguon_so_lieu', 'dinh_ky'],
#       dtype='str')

# %%
df_adl, df_adl_input_status = await client.read_excel_many(
    list_path_excel,
    sheet="ADL input",
    on_error="skip",
    on_missing_sheet="skip",
    skiprows=1,
    return_status=True,
    usecols="A:I",
)
# display(df_adl.head())
# display(df_adl_input_status)

df_adl.columns
# Out:
# Index(['Phân cấp đơn vị', 'Mã đơn vị', 'Tên đơn vị', 'Năm',
#        'Giai đoạn ngành\n(Industry Lifecycle) ▼',
#        'Vị thế cạnh tranh\n(Competition) ▼', 'Mức độ\ntin cậy ▼',
#        'Cơ sở đánh giá / Rationale\n(ngành, DN, market...)',
#        'Thị phần\nước tính (%)', '_source'],
#       dtype='str')

# %%
column_mapping = {
    "Phân cấp đơn vị": "phan_cap_don_vi",
    "Mã đơn vị": "ma_don_vi",
    "Tên đơn vị": "ten_don_vi",
    "Năm": "nam",
    "Giai đoạn ngành\n(Industry Lifecycle) ▼": "giai_doan_nganh",
    "Vị thế cạnh tranh\n(Competition) ▼": "vi_the_canh_tranh",
    "Mức độ\ntin cậy ▼": "muc_do_tin_cay",
    "Cơ sở đánh giá / Rationale\n(ngành, DN, market...)": "co_so_danh_gia",
    "Thị phần\nước tính (%)": "thi_phan_uoc_tinh",
    "_source": "source",
}
df_adl = df_adl.rename(columns=column_mapping)
df_adl = df_adl[list(column_mapping.values())]
# display(df_adl.head())
df_adl.columns
# Out:
# Index(['phan_cap_don_vi', 'ma_don_vi', 'ten_don_vi', 'nam', 'giai_doan_nganh',
#        'vi_the_canh_tranh', 'muc_do_tin_cay', 'co_so_danh_gia',
#        'thi_phan_uoc_tinh', 'source'],
#       dtype='str')

# %%
df_summary = df_list_files.copy()

for status_df, col in [
    (df_report_status, "report"),
    (df_key_drivers_status, "key_drivers"),
    (df_ratio_commit_status, "ratio_commit"),
    (df_adl_input_status, "adl_input"),
]:
    df_summary = df_summary.merge(
        status_df[["path", "status"]].rename(
            columns={
                "path": "file_path",
                "status": f"{col}_status",
            }
        ),
        on="file_path",
        how="left",
    )

display(df_summary[~df_summary["folder_name"].str.startswith("00")])
# Out:
#         folder_name                                             folder_path  \
# 2         01. GELEX        2026/Project Phoenix/04. Working files/01. GELEX
# 3           02. GEE          2026/Project Phoenix/04. Working files/02. GEE
# 4        03. CADIVI       2026/Project Phoenix/04. Working files/03. CADIVI
# 5           04. CMB          2026/Project Phoenix/04. Working files/04. CMB
# 6           05. THI          2026/Project Phoenix/04. Working files/05. THI
# 7           06. MEE          2026/Project Phoenix/04. Working files/06. MEE
# 8           07. HEM          2026/Project Phoenix/04. Working files/07. HEM
# 9          08. EMIC         2026/Project Phoenix/04. Working files/08. EMIC
# 10          09. CFT          2026/Project Phoenix/04. Working files/09. CFT
# 11     10. Phatdien     2026/Project Phoenix/04. Working files/10. Phatdien
# 12         11. GETC         2026/Project Phoenix/04. Working files/11. GETC
# 13         11. GETC         2026/Project Phoenix/04. Working files/11. GETC
# 14    12. GELEXTECH    2026/Project Phoenix/04. Working files/12. GELEXTECH
# 15  13. GELEXINVEST  2026/Project Phoenix/04. Working files/13. GELEXINVEST
# 16          14. GEL          2026/Project Phoenix/04. Working files/14. GEL
# 17          15. VGC          2026/Project Phoenix/04. Working files/15. VGC
# 18    16. Viwasupco    2026/Project Phoenix/04. Working files/16. Viwasupco
# 19          17. PXL          2026/Project Phoenix/04. Working files/17. PXL
# 20          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 21          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 22          18. FIH          2026/Project Phoenix/04. Working files/18. FIH
# 23      19. TITANHP      2026/Project Phoenix/04. Working files/19. TITANHP
# 24       20. WADACO       2026/Project Phoenix/04. Working files/20. WADACO
# 25    21. TitanCorp    2026/Project Phoenix/04. Working files/21. TitanCorp
# 26         22. BSG1         2026/Project Phoenix/04. Working files/22. BSG1
# 27         23. BSG2         2026/Project Phoenix/04. Working files/23. BSG2
# 28          24. TTP          2026/Project Phoenix/04. Working files/24. TTP
# 29          25. EIB          2026/Project Phoenix/04. Working files/25. EIB
#
#                                        file_name  \
# 2                GELEX_CFForecast_2026_2030.xlsb
# 3                                            NaN
# 4                    KH_CADIVI_5Y_29Apr2026.xlsx
# 5                                            NaN
# 6                   KH_THIBIDI_5Y_29Apr2026.xlsm
# 7                  MEE_CFForecast_2026_2030.xlsx
# 8                [HEM]_CFForecast_2026_2030.xlsx
# 9                 EMIC_CFForecast_2026_2030.xlsx
# 10                      KH_CFT_5Y_29Apr2026.xlsx
# 11            Phatdien_CFForecast_2026_2030.xlsx
# 12                GETC_CFForecast_2026_2030.xlsx
# 13              GETCHY_CFForecast_2026_2030.xlsx
# 14           GELEXTECH_CFForecast_2026_2030.xlsx
# 15         GELEXINVEST_CFForecast_2026_2030.xlsx
# 16               [GEL]_CFForecast_2026_2030.xlsm
# 17    VGC_CF me 2026-2030_form riêng_6.5.26.xlsx
# 18                  Viwasupco_CF_5Y_06.5.26.xlsm
# 19                              KH_PXL_5Y_2.xlsx
# 20            Citynest_CFForecast_2026_2030.xlsm
# 21           Kim Trang_CFForecast_2026_2030.xlsm
# 22             Landora_CFForecast_2026_2030.xlsm
# 23         Titan HP IP_CFForecast_2026_2030.xlsm
# 24                     WADACO_CF_5Y_06.5.26.xlsm
# 25          Titan Corp_CFForecast_2026_2030.xlsm
# 26  [BSG1]_CFForecast_2026_2030_1 - Bac SG1.xlsm
# 27  [BSG2]_CFForecast_2026_2030_1 - Bac SG2.xlsm
# 28               [TTP]_CFForecast_2026_2030.xlsm
# 29                 EIB_CFForecast_2026_2030.xlsm
#
#                                                                                        file_path  \
# 2               2026/Project Phoenix/04. Working files/01. GELEX/GELEX_CFForecast_2026_2030.xlsb
# 3                                                                                            NaN
# 4                  2026/Project Phoenix/04. Working files/03. CADIVI/KH_CADIVI_5Y_29Apr2026.xlsx
# 5                                                                                            NaN
# 6                    2026/Project Phoenix/04. Working files/05. THI/KH_THIBIDI_5Y_29Apr2026.xlsm
# 7                   2026/Project Phoenix/04. Working files/06. MEE/MEE_CFForecast_2026_2030.xlsx
# 8                 2026/Project Phoenix/04. Working files/07. HEM/[HEM]_CFForecast_2026_2030.xlsx
# 9                 2026/Project Phoenix/04. Working files/08. EMIC/EMIC_CFForecast_2026_2030.xlsx
# 10                       2026/Project Phoenix/04. Working files/09. CFT/KH_CFT_5Y_29Apr2026.xlsx
# 11        2026/Project Phoenix/04. Working files/10. Phatdien/Phatdien_CFForecast_2026_2030.xlsx
# 12                2026/Project Phoenix/04. Working files/11. GETC/GETC_CFForecast_2026_2030.xlsx
# 13              2026/Project Phoenix/04. Working files/11. GETC/GETCHY_CFForecast_2026_2030.xlsx
# 14      2026/Project Phoenix/04. Working files/12. GELEXTECH/GELEXTECH_CFForecast_2026_2030.xlsx
# 15  2026/Project Phoenix/04. Working files/13. GELEXINVEST/GELEXINVEST_CFForecast_2026_2030.xlsx
# 16                2026/Project Phoenix/04. Working files/14. GEL/[GEL]_CFForecast_2026_2030.xlsm
# 17     2026/Project Phoenix/04. Working files/15. VGC/VGC_CF me 2026-2030_form riêng_6.5.26.xlsx
# 18             2026/Project Phoenix/04. Working files/16. Viwasupco/Viwasupco_CF_5Y_06.5.26.xlsm
# 19                               2026/Project Phoenix/04. Working files/17. PXL/KH_PXL_5Y_2.xlsx
# 20             2026/Project Phoenix/04. Working files/18. FIH/Citynest_CFForecast_2026_2030.xlsm
# 21            2026/Project Phoenix/04. Working files/18. FIH/Kim Trang_CFForecast_2026_2030.xlsm
# 22              2026/Project Phoenix/04. Working files/18. FIH/Landora_CFForecast_2026_2030.xlsm
# 23      2026/Project Phoenix/04. Working files/19. TITANHP/Titan HP IP_CFForecast_2026_2030.xlsm
# 24                   2026/Project Phoenix/04. Working files/20. WADACO/WADACO_CF_5Y_06.5.26.xlsm
# 25     2026/Project Phoenix/04. Working files/21. TitanCorp/Titan Corp_CFForecast_2026_2030.xlsm
# 26  2026/Project Phoenix/04. Working files/22. BSG1/[BSG1]_CFForecast_2026_2030_1 - Bac SG1.xlsm
# 27  2026/Project Phoenix/04. Working files/23. BSG2/[BSG2]_CFForecast_2026_2030_1 - Bac SG2.xlsm
# 28                2026/Project Phoenix/04. Working files/24. TTP/[TTP]_CFForecast_2026_2030.xlsm
# 29                  2026/Project Phoenix/04. Working files/25. EIB/EIB_CFForecast_2026_2030.xlsm
#
#                file_modified  report_status key_drivers_status  \
# 2  2026-05-07 06:30:51+00:00        success            success
# 3                        NaT            NaN                NaN
# 4  2026-05-06 10:11:37+00:00        success            success
# 5                        NaT            NaN                NaN
# 6  2026-05-05 01:56:42+00:00        success            success
# 7  2026-05-07 06:17:18+00:00        success            success
# 8  2026-05-07 06:19:38+00:00        success            success
# 9  2026-05-07 06:22:00+00:00        success            success
# 10 2026-05-04 02:52:32+00:00        success            success
# 11 2026-05-05 01:19:35+00:00        success            success
# 12 2026-05-05 01:26:28+00:00        success            success
# 13 2026-05-05 01:24:43+00:00        success            success
# 14 2026-05-06 10:26:26+00:00        success            success
# 15 2026-05-05 01:23:08+00:00        success            success
# 16 2026-05-06 10:11:36+00:00        success            success
# 17 2026-05-06 10:09:34+00:00  missing_sheet            success
# 18 2026-05-06 10:08:55+00:00        success            success
# 19 2026-05-03 15:46:32+00:00        success            success
# 20 2026-05-07 04:06:21+00:00        success            success
# 21 2026-05-07 04:07:00+00:00        success            success
# 22 2026-05-07 04:07:34+00:00        success            success
# 23 2026-05-07 03:54:10+00:00        success            success
# 24 2026-05-06 10:09:14+00:00        success            success
# 25 2026-05-07 03:55:39+00:00        success            success
# 26 2026-05-07 06:42:45+00:00        success            success
# 27 2026-05-07 06:42:46+00:00        success            success
# 28 2026-05-04 01:45:01+00:00        success            success
# 29 2026-05-05 10:01:30+00:00        success            success
#
#    ratio_commit_status adl_input_status
# 2              success    missing_sheet
# 3                  NaN              NaN
# 4              success          success
# 5                  NaN              NaN
# 6              success          success
# 7              success    missing_sheet
# 8              success    missing_sheet
# 9              success    missing_sheet
# 10             success          success
# 11             success    missing_sheet
# 12             success    missing_sheet
# 13             success    missing_sheet
# 14             success    missing_sheet
# 15             success    missing_sheet
# 16             success    missing_sheet
# 17       missing_sheet    missing_sheet
# 18             success    missing_sheet
# 19       missing_sheet    missing_sheet
# 20             success    missing_sheet
# 21             success    missing_sheet
# 22             success    missing_sheet
# 23             success    missing_sheet
# 24       missing_sheet    missing_sheet
# 25             success    missing_sheet
# 26             success    missing_sheet
# 27             success    missing_sheet
# 28             success    missing_sheet
# 29             success    missing_sheet
